# %% [markdown]
# # Homework 2
#
# ### Due Date: Friday, March 20
#
# ### Policy Gradient
#
# In this assignment, we will implement vanilla policy gradient algorithm (REINFORCE) covered in the lecture. You will work on i) a function approximator, ii) computing action, iii) collecting samples, iV) training the agent, V) plotting the resutls.
#
#
# ***Complete the missing operations and test your implemented algorithm on the Gym environment.***
#
# ***Software requirements:***
# - Python >= 3.6
# - Tensorflow version <= 1.15.3 (1.X version)
# - OpenAI Gym
#
# - Training the agent (policy) can take long time. It is recomended to start solving the problems earlier.
#
# - Save any plots you generated in this notebook. The grade will be given based on the plots you showed.

# %% [markdown]
# Make sure the packages you installed meet the requirements.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.3'

# %%
import gym
gym.__version__
# Out:
# '0.17.3'

# %% [markdown]
# ## 1.1 Tensorflow Implementation
#
# We will be implementing policy gradient algorithm using Tensorflow 1.X., which simply updates the parameters of policy from obtaining gradient estimates. The core of policy gradient is to design a function approximator, computing actions, collecting samples, and training the policy. In the below cell, you are encouraged to fill in the components that are missing. ***Your tasks*** are
#
# 1. Complete the 'create_model' method to output the mean value for diagonal Guassian policy. Covariance is already defined in the model, so focus on creating neural network model.
#
# 2. Complete the 'action_op' method to calculate and return the actions for diagonal Gaussian policy. The applied action should be $\pi(s) = \pi_{\text{mean}}(s) + exp(logstd) * \mathcal{N}(0,1)$
#
# ***Hints***:
# - Some useful tensorflow classes and methods include: 'tf.exp', 'tf.random_normal'

# %% [markdown]
# ***IF you are using MAC, please run below box***

# %%
import os
# MAC user only
#os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import tensorflow as tf
import numpy as np
import os
#import ipdb


class PolicyOpt(object):

    def __init__(self, env, linear=False, stochastic=True, hidden_size=32, nonlinearity=tf.nn.relu):
        """Instantiate the policy iteration class.

        This initializes the policy optimization with a set of trainable 
        parameters, and creates a tensorflow session.

        Attributes
        ----------
        env : gym.Env
            the environment that the policy will be trained on
        linear : bool, optional
            specifies whether to use a linear or neural network 
            policy, defaults to False (i.e. Fully-Connected-Neural-Network)
        stochastic : bool, optional
            specifies whether to use a stochastic or deterministic 
            policy, defaults to True
        hidden_size : list of int, optional
            list of hidden layers, with each value corresponding 
            to the number of nodes in that layer 
        nonlinearity : tf.nn.*
            activation nonlinearity
        """
        
        # clear computation graph
        tf.reset_default_graph()
        
        # set a random seed
        tf.set_random_seed(1234)
        
        # start a tensorflow session
        self.sess = tf.Session()
        
        # environment to train on
        self.env = env
        
        # number of elements in the action space
        self.ac_dim = env.action_space.shape[0]
        
        # number of elements in the observation space
        self.obs_dim = env.observation_space.shape[0]

        # actions placeholder
        self.a_t_ph = tf.placeholder(dtype=tf.float32, 
                                     shape=[None, self.ac_dim])
        # state placeholder
        self.s_t_ph = tf.placeholder(dtype=tf.float32, 
                                     shape=[None, self.obs_dim])
        # expected reward placeholder
        self.rew_ph = tf.placeholder(dtype=tf.float32, 
                                     shape=[None, self.ac_dim])

#         self.input_ph = tf.placeholder(dtype=tf.float32, 
#                                      shape=[None, self.obs_dim])
        
        # specifies whether the policy is stochastic
        self.stochastic = stochastic

        # policy that the agent executes during training/testing
        self.policy = self.create_model(
            args={
                "num_actions": self.ac_dim,
                "hidden_size": hidden_size,
                "linear": linear,
                "nonlinearity": nonlinearity,
                "stochastic": stochastic,
                "scope": "policy",
            }
        )
        
        # define symbolic action
        self.symbolic_action = self.action_op()

        # initialize all variables
        self.sess.run(tf.global_variables_initializer())

        # create saver to save model variables
        self.saver = tf.train.Saver()

    def create_model(self, args):
        """Create a model for your policy or other components.

        Parameters
        ----------
        args : dict
            model-specific arguments, with keys:
              - "stochastic": True by default
              - "hidden_size": Number of neurons in hidden layer
              - "num_actions" number of output actions
              - "scope": scope of the model

        Returns
        -------
        tf.Variable
            mean actions of the policy
        tf.Variable 
            logstd of the policy actions
        """

#################### Build Your Neural Network Here! ####################    

        num_features = self.obs_dim
        num_hidden = args["hidden_size"]
        num_outputs = args["num_actions"]
        
        input_ph = [[0.,0.,0.]]
        
        weights_0 = tf.Variable(tf.random_normal([num_features,num_hidden]))
        bias_0 = tf.Variable(tf.random_normal([num_hidden]))
        weights_1 = tf.Variable(tf.random_normal([num_hidden,num_hidden]))
        bias_1 = tf.Variable(tf.random_normal([num_hidden]))
        weights_2 = tf.Variable(tf.random_normal([num_hidden,num_outputs]))
        bias_2 = tf.Variable(tf.random_normal([num_outputs]))

        # replaced relu with tanh
        hidden_layer1 = tf.nn.relu(tf.matmul(input_ph,weights_0)+bias_0)
        hidden_layer2 = tf.nn.relu(tf.matmul(hidden_layer1,weights_1)+bias_1)
        output_layer = tf.matmul(hidden_layer2,weights_2)+bias_2
        output_mean = tf.reduce_mean(output_layer,1)
        
##########################################################################        

        if args["stochastic"]:
            output_logstd =  tf.get_variable(name="action_logstd",shape=[self.ac_dim],trainable=True)
        else:
            output_logstd = None

        return output_mean, output_logstd
    
    def action_op(self):
        """
        Create a symbolic expression that will be used to compute actions from observations.

        When the policy is stochastic, the action follows 

            a_t = output_mean + exp(output_logstd) * z; z ~ N(0,1)
        """
        if self.stochastic:
            output_mean, output_logstd = self.policy

            #################### Implement a stochastic policy here ####################        
            # Implement a stochastic version of computing actions.       #
            #                                                            #
            # The action in a stochastic policy represented by           #
            # a diagonal Gaussian distribution with mean "M" and log     #
            # standard deviation "logstd" is computed as follows:        #
            #                                                            #
            #     a = M + exp(logstd) * z                                #
            #                                                            #
            # where z is a random normal value, i.e. z ~ N(0,1)          #
            #                                                            #
            # In order to generate numbers from a normal distribution,   #
            # use the `tf.random_normal` function.                       #
            ############################################################################ 
            z = tf.random_normal(tf.shape(output_logstd))
            symbolic_action = output_mean + tf.exp(output_logstd) * z 
            
        else:
            symbolic_action, _ = self.policy
        
        return symbolic_action

    def compute_action(self, obs):
        """Returns a list of actions for a given observation.

        Parameters
        ----------
        obs : np.ndarray
            observations

        Returns
        -------
        np.ndarray
            actions by the policy for a given observation
        """
        return self.sess.run(self.symbolic_action,feed_dict={self.s_t_ph: obs})

    def rollout(self, s_mean=None, s_std=None):
        """Collect samples from one rollout of the policy.

        Returns
        -------
        dict
            dictionary containing trajectory information for the rollout,
            specifically containing keys for "state", "action", "next_state", "reward", and "done"
        """
        states = []
        next_states = []
        actions = []
        rewards = []
        dones = []

        # start a new rollout by re-setting the environment and collecting the initial state
        state =  self.env.reset()

        steps = 0
        while True:
            steps += 1

            # compute the action given the state
            if s_mean is not None and s_std is not None:
                action = self.compute_action([(state - s_mean) / s_std])
            else:
                action = self.compute_action([state])
            action = action[0]

            # advance the environment once and collect the next state, reward, done, and info parameters from the environment
            next_state, reward, done, info =  self.env.step([action])

            # add to the samples list
            states.append(state)
            actions.append(action)
            next_states.append(next_state)
            rewards.append(reward)
            dones.append(done)

            state = next_state

            # if the environment returns a True for the done parameter,
            # end the rollout before the time horizon is met
            if done or steps > env._max_episode_steps:
                break

        # create the output trajectory
        trajectory = {"state": np.array(states, dtype=np.float32),
                      "reward": np.array(rewards, dtype=np.float32),
                      "action": np.array(actions, dtype=np.float32),
                      "next_state": np.array(next_states, dtype=np.float32),
                      "done": np.array(dones, dtype=np.float32)}

        return trajectory

    def train(self, args):
        """Abstract training method.

        This method will be filled in by algorithm-specific
        training operations in subsequent problems.

        Parameters
        ----------
        args : dict
            algorithm-specific hyperparameters
        """
        raise NotImplementedError

# %% [markdown]
# ## 1.2 Tensorflow Interpretation
#
# In order to test your implementation of the **stochastic policy**, run the below cell. The task is to interpret the code you implemented in previous section. If you implement correctly, you can see the value_1 and value_2.
#
# ***Question: How do you interpret value_1 and value_2 below cell?***

# %%
import gym
TEST_ENV = gym.make("Pendulum-v0")

alg = PolicyOpt(TEST_ENV, linear=False)
input_1 = [[0, 1, 2]]
value_1 = alg.sess.run(alg.policy[0], feed_dict={alg.s_t_ph: input_1})
value_2 = alg.compute_action(input_1)

# %%
value_1
# Out:
# array([-28.30414], dtype=float32)

# %% [markdown]
# Answer:

# %%
value_2
# Out:
# array([-27.565832], dtype=float32)

# %% [markdown]
# Answer:

# %% [markdown]
# ## 1.3 Implement Policy Gradient
#
# In this section, we will implement REINFORCE algorithm presented in the lecture. As a review, the objective is optimize the parameters $\theta$ of some policy $\pi_\theta$ so that the expected return
#
# \begin{equation}
# J(\theta) = \mathbb{E} \bigg\{ \sum_{t=0}^T \gamma^t r(s_{t},a_{t}) \bigg\}
# \end{equation}
#
# is optimized. In this algorithm, this is done by calculating the gradient $\nabla_\theta J$ and applying a gradient descent method to find a better policy.
#
# \begin{equation}
# \theta ' = \theta + \alpha \nabla_\theta J(\theta)
# \end{equation}
#
# In the lecture, we derive how we compute $\nabla_{\theta} J(\theta)$. We can rewrite our policy gradient as:
#
# \begin{equation}
# \nabla_\theta J (\theta) \approx \frac{1}{N} \sum_{i=0}^{N} \bigg( \sum_{t=0}^{T} \nabla_\theta \log \pi_\theta (a_{it} | s_{it}) \bigg) \bigg( \sum_{t=0}^T \gamma^{t}r_i(t) \bigg)
# \end{equation}
#
# Finally, taking into account the causality principle discussed in class, we are able to simplifiy the gradient estimate such as:
#
# \begin{equation}
# \nabla_\theta J (\theta) \approx \frac{1}{N} \sum_{i=0}^{N} \sum_{t=0}^{T} \nabla_\theta \log \pi_\theta (a_{it} | s_{it}) \sum_{t'=t}^T \gamma^{t'-t}r_i(t')
# \end{equation}
#
# You will be implementing final expression in this assignment!

# %% [markdown]
# The process of REINFOCE algorithm follows:
#
# 1. Collect samples from current policy $\pi_\theta(s)$ by executing rollouts of the environment.
# 2. Calculate an estimate for the expected return at state $s_t$.
# 3. Compute the log-likelihood of each action that was performed by the policy at every given step.
# 4. Estimate the gradient and update the parameters of policy using gradient-based technique.
# 5. Repeat steps 1-4 for a number of training iterations.
#
# ***Your task*** is to fill out the skeleton code for REINFORCE algorithm,
#
# 1. Complete the 'log_likelihoods' method to compute gradient of policy, $\nabla_{\theta}\pi_{\theta}$ for diagonal Guassian policy.
#
# 2. Complete the 'compute_expected_return' method to calculate the reward-to-go, $\sum_{t^{\prime}=t}^{T}$.

# %%
import tensorflow as tf
import numpy as np
import time
import tensorflow_probability as tfp # pip install tensorflow_probability==0.7

class REINFORCE(PolicyOpt):

    def train(self, num_iterations=1000, steps_per_iteration=1000, learning_rate=int(1e-4), gamma=0.95, 
              **kwargs):
        """Perform the REINFORE training operation.

        Parameters
        ----------
        num_iterations : int
            number of training iterations
        steps_per_iteration : int
            number of individual samples collected every training iteration
        learning_rate : float
            optimizer learning rate
        gamma : float
            discount rate
        kwargs : dict
            additional arguments

        Returns
        -------
        list of float
            average return per iteration
        """
        # set the discount as an attribute
        self.gamma = gamma
        
        # set the learning rate as an attribute
        self.learning_rate = learning_rate

        # create a symbolic expression to compute the log-likelihoods 
        log_likelihoods = self.log_likelihoods()

        # create a symbolic expression for updating the parameters of your policy
        self.opt, self.opt_baseline = self.define_updates(log_likelihoods)
        
        # initialize all variables
        self.sess.run(tf.global_variables_initializer())


        # average return per training iteration
        ret_per_iteration = []
        
        samples = []
        for i in range(num_iterations):
            
            # collect samples from the current policy
            samples.clear()
            steps_so_far = 0
            while steps_so_far < steps_per_iteration:
                new_samples = self.rollout()
                steps_so_far += new_samples["action"].shape[0]
                samples.append(new_samples)

            # compute the expected returns
            v_s = self.compute_expected_return(samples)

           
            # compute and apply the gradients
            self.call_updates(log_likelihoods, samples, v_s, **kwargs)

            # compute the average cumulative return per iteration
            average_rew = np.mean([sum(s["reward"]) for s in samples])

            # display iteration statistics
            print("Iteration {} return: {}".format(i, average_rew))
            ret_per_iteration.append(average_rew)

        return ret_per_iteration

    def log_likelihoods(self):
        """Create a tensorflow operation that computes the log-likelihood 
        of each performed action.
        """
        
        output_mean, output_logstd = self.policy

        ##############################################################
        # Create a tf operation to compute the log-likelihood of     #
        # each action that was performed by the policy               #
        #                                                            #
        # The log likelihood in the continuous case where the policy #
        # is expressed by a multivariate gaussian can be computing   #
        # using the tensorflow object:                               #
        #                                                            #
        #    p = tfp.distributions.MultivariateNormalDiag(           #
        #        loc=...,                                            #
        #        scale_diag=...,                                     #
        #    )                                                       #
        #                                                            #
        # This method takes as input a mean (loc) and standard       #
        # deviation (scale_diag), and then can be used to compute    #
        # the log-likelihood of a variable as follows:               #
        #                                                            #
        #    log_likelihoods = p.log_prob(...)                       #
        #                                                            #
        # For this operation, you will want to use placeholders      #
        # created in the __init__ method of problem 1.               #
        ##############################################################

        p = tfp.distributions.MultivariateNormalDiag(           
               loc=output_mean,                                            
               scale_diag=tf.exp(output_logstd),                                     
           )       
        log_likelihoods = p.log_prob([[0.]]) 

        return log_likelihoods

    def compute_expected_return(self, samples):
        """Compute the expected return from a given starting state.
        This is done by using the reward-to-go method.

        Parameters
        ----------
        rewards : list of list of float
            a list of N trajectories, with each trajectory contain T 
            returns values (one for each step in the trajectory)

        Returns
        -------
        list of float, or np.ndarray
            expected returns for each step in each trajectory
        """
        rewards = [s["reward"] for s in samples]
#         print(rewards)

        ##############################################################
        # Estimate the expected return from any given starting state #
        # using the reward-to-go method.                             #
        #                                                            #
        # Using this method, the reward is estimated at every step   #
        # of the trajectory as follows:                              #
        #                                                            #
        #   r = sum_{t'=t}^T gamma^(t'-t) * r_{t'}                   #
        #                                                            #
        # where T is the time horizon at t is the index of the       #
        # current reward in the trajectory. For example, for a given #
        # set of rewards r = [1,1,1,1] and discount rate gamma = 1,  #
        # the expected reward-to-go would be:                        #
        #                                                            #
        #   v_s = [4, 3, 2, 1]                                       #
        #                                                            #
        # You will be able to test this in one of the cells below!   #
        ##############################################################
        v_s = []
        for r in rewards:
            s = [0]*len(r)
            for t in range(0,len(r)):
                for tprime in range(t, len(r)):
                    s[t] += self.gamma**(tprime-t) * r[tprime]
            v_s +=s

#         print(v_s)
        
        return v_s

    def define_updates(self, log_likelihoods):
        """Create a tensorflow operation to update the parameters of 
        your policy.

        Parameters
        ----------
        log_likelihoods : tf.Operation
            the symbolic expression you created to estimate the log 
            likelihood of a set of actions

        Returns
        -------
        tf.Operation
            a tensorflow operation for computing and applying the 
            gradients to the parameters of the policy
        None
            the second component is used in problem 2.b, please ignore 
            for this problem
        """

        loss = - tf.reduce_mean(tf.multiply(log_likelihoods, self.rew_ph))
        opt = tf.train.AdamOptimizer(self.learning_rate).minimize(loss)

        return opt, None

    def call_updates(self, log_likelihoods, samples, v_s, **kwargs):
        """Apply the gradient update methods in a tensorflow session.

        Parameters
        ----------
        log_likelihoods: tf.Operation
            the symbolic expression you created to estimate the log 
            likelihood of a set of actions
        samples : list of dict
            a list of N trajectories, with each trajectory containing 
            a dictionary of trajectory data (see self.rollout)
        v_s : list of float, or np.ndarray
            the estimated expected returns from your
            `comput_expected_return` function 
        kwargs : dict
            additional arguments (used in question 3)
        """
        # concatenate the states
        states = np.concatenate([s["state"] for s in samples])

        # concatenate the actions
        actions = np.concatenate([s["action"] for s in samples])

        v_s = np.expand_dims(np.array(v_s), axis=1) #np.array(v_s).reshape(len(v_s), 1)
        actions = np.expand_dims(np.array(actions), axis=1)
#         print(v_s.shape)
#         print(states.shape)
#         print(actions.shape)
        # execute the optimization step
        self.sess.run(self.opt, feed_dict={self.s_t_ph: states,
                                           self.a_t_ph: actions,
                                           self.rew_ph: v_s})

# %% [markdown]
# Check your 'log_likelihoods' method by running below cell:

# %%
alg = REINFORCE(TEST_ENV, stochastic=True)

log_likelihoods = alg.log_likelihoods()

# collect a sample output for a given input state
input_s = [[0, 0, 0], [0, 1, 2], [1, 2, 3]]
input_a = [[0], [1], [2]]

# Check
computed = alg.sess.run(log_likelihoods, feed_dict={alg.a_t_ph: input_a, alg.s_t_ph: input_s})

# %% [markdown]
# Test your 'compute_expected_return' by running below cell:

# %%
# 1. Test the non-normalized case
alg = REINFORCE(TEST_ENV, stochastic=True)
alg.gamma = 1.0
    
input_1 = [{"reward": [1, 1, 1, 1]},
           {"reward": [1, 1, 1, 1]}]
vs_1 = alg.compute_expected_return(samples=input_1)
ans_1 = np.array([4, 3, 2, 1, 4, 3, 2, 1])

if np.linalg.norm(vs_1 - ans_1) < 1e-3:
    print('Great job!')
else:
    print('Check your implementation (compute_expected_return)')
# Out:
# Great job!

# %% [markdown]
# ## 1.4 Testing your algorithm
#
# When you are ready, test your policy gradient algorithms on the *Pendulum-v0* environment in the cell below. *Pendulum-v0* environment is similar to *off-shore wind power*, the goal here is to maintain the Pendulum is upright using control input. The best policy should get around -200 scores. ***Your task*** is to run your REINFORCE algorithm and plot the result!

# %%
# set this number as 1 for testing your algorithm, and 3 for plotting
NUM_TRIALS = 3

# ===========================================================================
# Do not modify below line
# ===========================================================================

# we will test the algorithms on the Pendulum-v0 gym environment
import gym
env = gym.make("Pendulum-v0")

# train on the REINFORCE algorithm
import numpy as np
r = []
for i in range(NUM_TRIALS):
    print("\n==== Training Run {} ====".format(i))
    alg = REINFORCE(env, stochastic=True)
#     alg.a_t_ph = tf.zeros([1,1], dtype=tf.float32)
#     alg.s_t_ph = tf.zeros([1,3], dtype=tf.float32)
    res = alg.train(learning_rate=0.005, gamma=0.95, num_iterations=500, steps_per_iteration=15000)
    r.append(np.array(res))
    alg = None

# save results
np.savetxt("InvertedPendulum_results.csv", np.array(r), delimiter=",")
# Out:
# ==== Training Run 0 ====
# Iteration 0 return: -1471.0733907116328
# Iteration 1 return: -1384.5964111463975
# Iteration 2 return: -1400.6991818946663
# Iteration 3 return: -1440.0273269852562
# Iteration 4 return: -1449.5293189506979
# Iteration 5 return: -1416.4989278295511
# Iteration 6 return: -1444.8177103195835
# Iteration 7 return: -1399.7748650269832
# Iteration 8 return: -1436.5646002226322
# Iteration 9 return: -1421.3610305457687
# Iteration 10 return: -1400.895998064081
# Iteration 11 return: -1390.3518924594423
# Iteration 12 return: -1441.1175383153372
# Iteration 13 return: -1465.7714846751342
# Iteration 14 return: -1428.0565437672535
# Iteration 15 return: -1495.527034721474
# Iteration 16 return: -1410.7391411633043
# Iteration 17 return: -1455.628388532338
# Iteration 18 return: -1450.280686326176
# Iteration 19 return: -1426.6756423064508
# Iteration 20 return: -1411.0534528406524
# Iteration 21 return: -1408.4112879650108
# Iteration 22 return: -1410.2602615917908
# Iteration 23 return: -1414.0002949034672
# Iteration 24 return: -1452.0116891097525
# Iteration 25 return: -1435.3081657168268
# Iteration 26 return: -1401.268036616221
# Iteration 27 return: -1459.151543386678
# Iteration 28 return: -1390.2096363631883
# Iteration 29 return: -1409.6573085370162
# Iteration 30 return: -1378.4766009498885
# Iteration 31 return: -1451.5389008890154
# Iteration 32 return: -1427.008565122752
# Iteration 33 return: -1399.2338934682248
# Iteration 34 return: -1437.1362740822137
# Iteration 35 return: -1377.6679714981403
# Iteration 36 return: -1407.0239194000017
# Iteration 37 return: -1472.2798146521177
# Iteration 38 return: -1413.9501913125998
# Iteration 39 return: -1447.5567717472463
# Iteration 40 return: -1415.5960127403835
# Iteration 41 return: -1442.4582162026006
# Iteration 42 return: -1417.4197971501078
# Iteration 43 return: -1433.5840962301568
# Iteration 44 return: -1461.2692118165269
# Iteration 45 return: -1408.0880873452995
# Iteration 46 return: -1455.1644368273642
# Iteration 47 return: -1438.799401456366
# Iteration 48 return: -1453.8245342815915
# Iteration 49 return: -1422.0187808607022
# Iteration 50 return: -1449.7051077022961
# Iteration 51 return: -1423.820873447104
# Iteration 52 return: -1389.6176182575027
# Iteration 53 return: -1432.836095155577
# Iteration 54 return: -1416.8942422817709
# Iteration 55 return: -1428.6841237811495
# Iteration 56 return: -1429.7679047599436
# Iteration 57 return: -1450.8617342958723
# Iteration 58 return: -1412.2489606025815
# Iteration 59 return: -1488.4273230874787
# Iteration 60 return: -1461.212561644266
# Iteration 61 return: -1405.289143095414
# Iteration 62 return: -1368.2389922440673
# Iteration 63 return: -1461.3638560858556
# Iteration 64 return: -1418.9472348639742
# Iteration 65 return: -1423.2716277411207
# Iteration 66 return: -1410.0754826578745
# Iteration 67 return: -1448.8096338248004
# Iteration 68 return: -1453.1352759891004
# Iteration 69 return: -1441.393441311568
# Iteration 70 return: -1440.6706626561408
# Iteration 71 return: -1384.0350810010234
# Iteration 72 return: -1425.4907048810026
# Iteration 73 return: -1456.3429987608579
# Iteration 74 return: -1409.4997529675873
# Iteration 75 return: -1501.1458394638698
# Iteration 76 return: -1399.213586116458
# Iteration 77 return: -1466.955875510977
# Iteration 78 return: -1442.9437363734964
# Iteration 79 return: -1371.7314994903281
# Iteration 80 return: -1464.9969683222225
# Iteration 81 return: -1396.9657029040281
# Iteration 82 return: -1443.0132814669857
# Iteration 83 return: -1365.9372784053348
# Iteration 84 return: -1462.5962262379378
# Iteration 85 return: -1464.1397372694562
# Iteration 86 return: -1426.4582782050904
# Iteration 87 return: -1381.9418695412203
# Iteration 88 return: -1466.6888255655144
# Iteration 89 return: -1378.4947615688232
# Iteration 90 return: -1430.7584232212914
# Iteration 91 return: -1407.3857949018914
# Iteration 92 return: -1439.0770524305105
# Iteration 93 return: -1445.1617951398343
# Iteration 94 return: -1465.54416173039
# Iteration 95 return: -1450.1439632723418
# Iteration 96 return: -1439.9301634275603
# Iteration 97 return: -1437.2166316602131
# Iteration 98 return: -1433.8960207499315
# Iteration 99 return: -1426.394078673472
# Iteration 100 return: -1440.9866104302928
# Iteration 101 return: -1429.108098193792
# Iteration 102 return: -1435.5106356698648
# Iteration 103 return: -1442.841918120825
# Iteration 104 return: -1351.1371173732232
# Iteration 105 return: -1433.3795532527256
# Iteration 106 return: -1456.4642772651403
# Iteration 107 return: -1408.6512815422068
# Iteration 108 return: -1444.8505952568973
# Iteration 109 return: -1447.5675377142927
# Iteration 110 return: -1447.6091953075554
# Iteration 111 return: -1433.0056136040887
# Iteration 112 return: -1391.6761246759568
# Iteration 113 return: -1416.7008458831285
# Iteration 114 return: -1452.8069135930823
# Iteration 115 return: -1432.2626704293987
# Iteration 116 return: -1473.1930161736036
# Iteration 117 return: -1475.9977072744755
# Iteration 118 return: -1448.7504011037884
# Iteration 119 return: -1437.8823848062443
# Iteration 120 return: -1475.62327905771
# Iteration 121 return: -1383.1832645049878
# Iteration 122 return: -1391.2870990442732
# Iteration 123 return: -1399.9052485063114
# Iteration 124 return: -1456.3421988185992
# Iteration 125 return: -1484.806270707709
# Iteration 126 return: -1467.1796107997745
# Iteration 127 return: -1448.738377161883
# Iteration 128 return: -1438.6391587289795
# Iteration 129 return: -1431.692405674557
# Iteration 130 return: -1448.6986968011408
# Iteration 131 return: -1433.0853164859984
# Iteration 132 return: -1409.3121929885694
# Iteration 133 return: -1400.303285532867
# Iteration 134 return: -1396.9277928314234
# Iteration 135 return: -1388.5769831843675
# Iteration 136 return: -1393.1357287447217
# Iteration 137 return: -1426.7673032900318
# Iteration 138 return: -1400.5035471714662
# Iteration 139 return: -1454.0863073510366
# Iteration 140 return: -1400.5502492287071
# Iteration 141 return: -1445.3953830080354
# Iteration 142 return: -1463.1291616871517
# Iteration 143 return: -1391.4083662239898
# Iteration 144 return: -1434.2962924589465
# Iteration 145 return: -1447.859819878203
# Iteration 146 return: -1428.5261564431712
# Iteration 147 return: -1386.4321799849968
# Iteration 148 return: -1403.9358865231525
# Iteration 149 return: -1462.3326898385274
# Iteration 150 return: -1399.8191106731072
# Iteration 151 return: -1419.1446376155068
# Iteration 152 return: -1402.4525238295769
# Iteration 153 return: -1466.2872596395637
# Iteration 154 return: -1427.5254444533275
# Iteration 155 return: -1456.425576041937
# Iteration 156 return: -1467.0605229904752
# Iteration 157 return: -1465.7924532345185
# Iteration 158 return: -1422.918107874145
# Iteration 159 return: -1388.8459451199137
# Iteration 160 return: -1363.422796980124
# Iteration 161 return: -1415.4732722536412
# Iteration 162 return: -1402.5951276582975
# Iteration 163 return: -1447.3830643908927
# Iteration 164 return: -1427.5132031090309
# Iteration 165 return: -1434.1737836709308
# Iteration 166 return: -1389.7023144396892
# Iteration 167 return: -1430.6504682719956
# Iteration 168 return: -1420.3293927486986
# Iteration 169 return: -1459.8366250595761
# Iteration 170 return: -1400.5663297978044
# Iteration 171 return: -1407.3411423918978
# Iteration 172 return: -1436.1131719975795
# Iteration 173 return: -1405.7479929531303
# Iteration 174 return: -1434.4249997683614
# Iteration 175 return: -1422.355024324674
# Iteration 176 return: -1446.2200464612495
# Iteration 177 return: -1394.7002526225274
# Iteration 178 return: -1430.971996332556
# Iteration 179 return: -1421.415496364472
# Iteration 180 return: -1382.8605051965142
# Iteration 181 return: -1435.3931623125013
# Iteration 182 return: -1463.1150029728065
# Iteration 183 return: -1426.508782600686
# Iteration 184 return: -1382.3625444831698
# Iteration 185 return: -1422.9808337686893
# Iteration 186 return: -1377.9363571520212
# Iteration 187 return: -1400.744393729077
# Iteration 188 return: -1387.0902506068287
# Iteration 189 return: -1420.1565222010638
# Iteration 190 return: -1459.4985650471226
# Iteration 191 return: -1463.301518467143
# Iteration 192 return: -1472.513468030151
# Iteration 193 return: -1459.2051310375023
# Iteration 194 return: -1434.5552681879576
# Iteration 195 return: -1429.0712994456787
# Iteration 196 return: -1493.0408230401326
# Iteration 197 return: -1435.241744046112
# Iteration 198 return: -1435.4163752916206
# Iteration 199 return: -1398.0237042140216
# Iteration 200 return: -1448.853325095127
# Iteration 201 return: -1477.8521322773645
# Iteration 202 return: -1412.338920621872
# Iteration 203 return: -1427.3460271970246
# Iteration 204 return: -1473.8190653987106
# Iteration 205 return: -1434.759102371484
# Iteration 206 return: -1396.8058962290859
# Iteration 207 return: -1410.5316164800029
# Iteration 208 return: -1434.779949435927
# Iteration 209 return: -1438.8560299728438
# Iteration 210 return: -1399.4076238330579
# Iteration 211 return: -1434.2022737316538
# Iteration 212 return: -1444.107436106503
# Iteration 213 return: -1448.2855866933116
# Iteration 214 return: -1429.5779379141393
# Iteration 215 return: -1430.2186362937093
# Iteration 216 return: -1433.6812386822141
# Iteration 217 return: -1416.3577370380115
# Iteration 218 return: -1469.0146035246428
# Iteration 219 return: -1404.770690431868
# Iteration 220 return: -1389.1057344331964
# Iteration 221 return: -1421.3493898594131
# Iteration 222 return: -1434.6295202948154
# Iteration 223 return: -1443.946763410978
# Iteration 224 return: -1436.7924659247635
# Iteration 225 return: -1451.0616844180474
# Iteration 226 return: -1392.3354769025495
# Iteration 227 return: -1422.572582520762
# Iteration 228 return: -1440.414387310967
# Iteration 229 return: -1398.326990817599
# Iteration 230 return: -1440.1349949226155
# Iteration 231 return: -1444.5598515322495
# Iteration 232 return: -1452.3277264981716
# Iteration 233 return: -1439.3853280601713
# Iteration 234 return: -1402.288047522977
# Iteration 235 return: -1383.0882308276493
# Iteration 236 return: -1438.657056856354
# Iteration 237 return: -1472.508495304783
# Iteration 238 return: -1397.3622654360533
# Iteration 239 return: -1472.9834534451677
# Iteration 240 return: -1429.8653900652876
# Iteration 241 return: -1426.2281812955937
# Iteration 242 return: -1440.1452227124696
# Iteration 243 return: -1402.1818027187262
# Iteration 244 return: -1378.9621447567392
# Iteration 245 return: -1442.1034882616375
# Iteration 246 return: -1430.5883476166862
# Iteration 247 return: -1422.4566747837948
# Iteration 248 return: -1430.5868313995998
# Iteration 249 return: -1417.9948397017208
# Iteration 250 return: -1437.3628165160183
# Iteration 251 return: -1442.6113086592406
# Iteration 252 return: -1356.1093142638977
# Iteration 253 return: -1379.1796055734344
# Iteration 254 return: -1458.7838345086636
# Iteration 255 return: -1399.4211760547446
# Iteration 256 return: -1446.3614820366602
# Iteration 257 return: -1437.1556504051014
# Iteration 258 return: -1390.919941653895
# Iteration 259 return: -1416.0045259305834
# Iteration 260 return: -1438.8435790204753
# Iteration 261 return: -1461.3932323636611
# Iteration 262 return: -1383.9320787129552
# Iteration 263 return: -1434.7950585013505
# Iteration 264 return: -1443.8955552224938
# Iteration 265 return: -1449.7098652475327
# Iteration 266 return: -1424.5625735974063
# Iteration 267 return: -1431.1044409898916
# Iteration 268 return: -1428.3205624847735
# Iteration 269 return: -1443.8127345078128
# Iteration 270 return: -1434.2512493935662
# Iteration 271 return: -1400.8674154003586
# Iteration 272 return: -1447.478371690816
# Iteration 273 return: -1457.2530313555649
# Iteration 274 return: -1402.7685498491117
# Iteration 275 return: -1414.5774133473137
# Iteration 276 return: -1406.6074518940102
# Iteration 277 return: -1443.0091350476196
# Iteration 278 return: -1460.9895944056536
# Iteration 279 return: -1444.071104039997
# Iteration 280 return: -1406.085401290171
# Iteration 281 return: -1480.869852502315
# Iteration 282 return: -1454.5519478450715
# Iteration 283 return: -1411.2063422584038
# Iteration 284 return: -1422.59398858821
# Iteration 285 return: -1444.99142792151
# Iteration 286 return: -1417.2990485458076
# Iteration 287 return: -1424.9225209386957
# Iteration 288 return: -1427.0093281824143
# Iteration 289 return: -1367.2645624566824
# Iteration 290 return: -1457.9421270197008
# Iteration 291 return: -1385.9812467662741
# Iteration 292 return: -1456.9039356277137
# Iteration 293 return: -1421.582432951356
# Iteration 294 return: -1354.2891084628427
# Iteration 295 return: -1436.7785558121402
# Iteration 296 return: -1386.191833226954
# Iteration 297 return: -1391.5773726661255
# Iteration 298 return: -1419.3105634604208
# Iteration 299 return: -1406.5987089474002
# Iteration 300 return: -1416.0085377599237
# Iteration 301 return: -1462.0510081164725
# Iteration 302 return: -1470.9243580091247
# Iteration 303 return: -1408.6220220670104
# Iteration 304 return: -1427.0171812749156
# Iteration 305 return: -1398.1190928830704
# Iteration 306 return: -1416.9789869067197
# Iteration 307 return: -1431.1134838108655
# Iteration 308 return: -1431.2116858211657
# Iteration 309 return: -1427.9528295389812
# Iteration 310 return: -1432.4610835961748
# Iteration 311 return: -1436.8835007622217
# Iteration 312 return: -1395.4704920305312
# Iteration 313 return: -1456.5169404614965
# Iteration 314 return: -1406.1900742003074
# Iteration 315 return: -1458.987496852291
# Iteration 316 return: -1422.0814267895619
# Iteration 317 return: -1442.4777355382716
# Iteration 318 return: -1450.7829570219294
# Iteration 319 return: -1460.768452958775
# Iteration 320 return: -1436.5454737545301
# Iteration 321 return: -1407.9386288899059
# Iteration 322 return: -1430.0664016782368
# Iteration 323 return: -1433.5399935988337
# Iteration 324 return: -1460.1529245525599
# Iteration 325 return: -1450.0319150278779
# Iteration 326 return: -1422.5321877206488
# Iteration 327 return: -1422.3317696508268
# Iteration 328 return: -1385.4036714487772
# Iteration 329 return: -1400.957984675318
# Iteration 330 return: -1413.8049218790356
# Iteration 331 return: -1393.1258210672438
# Iteration 332 return: -1448.599811791312
# Iteration 333 return: -1442.0569396996996
# Iteration 334 return: -1456.5274640374755
# Iteration 335 return: -1427.8504246220614
# Iteration 336 return: -1423.157844238778
# Iteration 337 return: -1428.908769400927
# Iteration 338 return: -1471.3053476699938
# Iteration 339 return: -1457.1959964518808
# Iteration 340 return: -1478.683925156792
# Iteration 341 return: -1420.343444933798
# Iteration 342 return: -1454.2639415126666
# Iteration 343 return: -1387.927195269124
# Iteration 344 return: -1431.3962113614257
# Iteration 345 return: -1401.0549476888466
# Iteration 346 return: -1455.3118691616817
# Iteration 347 return: -1385.03331886972
# Iteration 348 return: -1486.104342786527
# Iteration 349 return: -1397.4144171833123
# Iteration 350 return: -1449.3033817594064
# Iteration 351 return: -1429.5932581457434
# Iteration 352 return: -1406.4638819488139
# Iteration 353 return: -1445.4478958048485
# Iteration 354 return: -1398.798675174564
# Iteration 355 return: -1428.2715516572198
# Iteration 356 return: -1457.126336274445
# Iteration 357 return: -1438.8191486863916
# Iteration 358 return: -1401.6237391462178
# Iteration 359 return: -1430.428503152579
# Iteration 360 return: -1446.8511315652852
# Iteration 361 return: -1413.0193441190074
# Iteration 362 return: -1408.1622806430858
# Iteration 363 return: -1417.0671269584943
# Iteration 364 return: -1391.149007958683
# Iteration 365 return: -1473.5615032874482
# Iteration 366 return: -1479.7294638139692
# Iteration 367 return: -1456.8611969400197
# Iteration 368 return: -1475.8312670487537
# Iteration 369 return: -1415.017340960093
# Iteration 370 return: -1447.2783255150853
# Iteration 371 return: -1477.9301394097693
# Iteration 372 return: -1401.7984684457879
# Iteration 373 return: -1426.851658199032
# Iteration 374 return: -1371.4788406270245
# Iteration 375 return: -1448.9502343431177
# Iteration 376 return: -1392.082130723459
# Iteration 377 return: -1411.8859599231555
# Iteration 378 return: -1373.691028073641
# Iteration 379 return: -1446.1407809573038
# Iteration 380 return: -1409.5723623220995
# Iteration 381 return: -1415.4596713498545
# Iteration 382 return: -1408.9087457211565
# Iteration 383 return: -1407.5878513678722
# Iteration 384 return: -1439.0887586634606
# Iteration 385 return: -1415.5878142756906
# Iteration 386 return: -1467.6061362460007
# Iteration 387 return: -1437.3850609831698
# Iteration 388 return: -1461.2483450478937
# Iteration 389 return: -1432.8895231224783
# Iteration 390 return: -1453.4764933869367
# Iteration 391 return: -1465.8605170141843
# Iteration 392 return: -1441.9477403155279
# Iteration 393 return: -1455.2712600235081
# Iteration 394 return: -1428.2965861943487
# Iteration 395 return: -1442.114778366598
# Iteration 396 return: -1451.4721536520744
# Iteration 397 return: -1462.6466695399706
# Iteration 398 return: -1430.3604411995907
# Iteration 399 return: -1443.4961615887719
# Iteration 400 return: -1402.9620821644367
# Iteration 401 return: -1416.0595647604453
# Iteration 402 return: -1442.6836377016268
# Iteration 403 return: -1423.6891177213688
# Iteration 404 return: -1433.5415408511833
# Iteration 405 return: -1420.7245511845747
# Iteration 406 return: -1462.1036419728646
# Iteration 407 return: -1433.4251570966467
# Iteration 408 return: -1464.2939996244386
# Iteration 409 return: -1479.8537204068155
# Iteration 410 return: -1454.7711838880803
# Iteration 411 return: -1456.3290794792274
# Iteration 412 return: -1416.9342878975222
# Iteration 413 return: -1459.5448185780645
# Iteration 414 return: -1399.6483237076736
# Iteration 415 return: -1385.8434689437474
# Iteration 416 return: -1353.9103406160573
# Iteration 417 return: -1447.6762843990762
# Iteration 418 return: -1472.4716587504372
# Iteration 419 return: -1458.608073587157
# Iteration 420 return: -1442.1263423826297
# Iteration 421 return: -1442.504508877347
# Iteration 422 return: -1441.9091573050432
# Iteration 423 return: -1472.9001695877128
# Iteration 424 return: -1423.9885143721972
# Iteration 425 return: -1428.880075006069
# Iteration 426 return: -1499.0825334577573
# Iteration 427 return: -1457.514144946933
# Iteration 428 return: -1430.7346317484726
# Iteration 429 return: -1503.6508059857538
# Iteration 430 return: -1452.402207383613
# Iteration 431 return: -1394.766381459795
# Iteration 432 return: -1444.4217716326007
# Iteration 433 return: -1401.2760732680558
# Iteration 434 return: -1502.3159845067064
# Iteration 435 return: -1460.8551096800963
# Iteration 436 return: -1441.4589668551707
# Iteration 437 return: -1426.011803408675
# Iteration 438 return: -1458.9156652268891
# Iteration 439 return: -1462.1428226644111
# Iteration 440 return: -1461.2217427501394
# Iteration 441 return: -1440.7147353807093
# Iteration 442 return: -1428.3934619421016
# Iteration 443 return: -1416.167809500955
# Iteration 444 return: -1391.6597264497107
# Iteration 445 return: -1423.8277728547155
# Iteration 446 return: -1412.1724747145984
# Iteration 447 return: -1409.1892886932442
# Iteration 448 return: -1486.712748765008
# Iteration 449 return: -1460.3485894013445
# Iteration 450 return: -1449.7321003294985
# Iteration 451 return: -1442.1577218633518
# Iteration 452 return: -1418.8342820188652
# Iteration 453 return: -1399.3085410612014
# Iteration 454 return: -1450.8846863600736
# Iteration 455 return: -1448.7015041111906
# Iteration 456 return: -1430.8253828862805
# Iteration 457 return: -1432.5488337224226
# Iteration 458 return: -1403.142885714459
# Iteration 459 return: -1426.0471193424116
# Iteration 460 return: -1409.4550289685528
# Iteration 461 return: -1434.4444918956422
# Iteration 462 return: -1434.8566552731643
# Iteration 463 return: -1418.4469145312098
# Iteration 464 return: -1423.2837177581464
# Iteration 465 return: -1440.1493215701357
# Iteration 466 return: -1459.4480931540331
# Iteration 467 return: -1375.0760204906016
# Iteration 468 return: -1449.1300125479077
# Iteration 469 return: -1424.0606021848196
# Iteration 470 return: -1421.2720576603897
# Iteration 471 return: -1401.9117701414848
# Iteration 472 return: -1404.7990879439067
# Iteration 473 return: -1435.8988512279404
# Iteration 474 return: -1447.4769983125354
# Iteration 475 return: -1431.225168690135
# Iteration 476 return: -1473.0208763320993
# Iteration 477 return: -1492.9405825437855
# Iteration 478 return: -1453.6713621065765
# Iteration 479 return: -1382.3690895125394
# Iteration 480 return: -1474.69031464234
# Iteration 481 return: -1382.5478714456594
# Iteration 482 return: -1468.731460888007
# Iteration 483 return: -1420.2819996607552
# Iteration 484 return: -1413.333894121386
# Iteration 485 return: -1414.0885068374002
# Iteration 486 return: -1453.40070030765
# Iteration 487 return: -1442.3675122907384
# Iteration 488 return: -1423.1107283003132
# Iteration 489 return: -1407.7298964796091
# Iteration 490 return: -1435.5530943519002
# Iteration 491 return: -1422.9595502016507
# Iteration 492 return: -1433.9037792525069
# Iteration 493 return: -1417.5929259594157
# Iteration 494 return: -1463.6536869418496
# Iteration 495 return: -1447.5519150066748
# Iteration 496 return: -1383.6584633520245
# Iteration 497 return: -1422.9624142000514
# Iteration 498 return: -1457.0897041615347
# Iteration 499 return: -1441.6634271914636
#
# ==== Training Run 1 ====
# Iteration 0 return: -1456.678722721959
# Iteration 1 return: -1411.7040068560218
# Iteration 2 return: -1404.5077482103184
# Iteration 3 return: -1456.3836739367496
# Iteration 4 return: -1476.6853621452487
# Iteration 5 return: -1421.733634573072
# Iteration 6 return: -1443.111404333214
# Iteration 7 return: -1378.938865336925
# Iteration 8 return: -1434.9291645392775
# Iteration 9 return: -1398.238191826089
# Iteration 10 return: -1453.7514142059285
# Iteration 11 return: -1444.7282984692665
# Iteration 12 return: -1435.2713718901575
# Iteration 13 return: -1406.7694542000443
# Iteration 14 return: -1433.8890464825245
# Iteration 15 return: -1462.9317205607394
# Iteration 16 return: -1407.5354556990787
# Iteration 17 return: -1446.7827340674896
# Iteration 18 return: -1387.0402966761155
# Iteration 19 return: -1404.304453168139
# Iteration 20 return: -1425.4832303432374
# Iteration 21 return: -1448.6393308735887
# Iteration 22 return: -1415.6963628546025
# Iteration 23 return: -1488.4098053142925
# Iteration 24 return: -1446.491450730705
# Iteration 25 return: -1444.3992026168107
# Iteration 26 return: -1433.2257928447984
# Iteration 27 return: -1457.2036225061615
# Iteration 28 return: -1448.6648564863888
# Iteration 29 return: -1452.8609136549135
# Iteration 30 return: -1447.9520868404832
# Iteration 31 return: -1443.4899962795898
# Iteration 32 return: -1421.0424827082206
# Iteration 33 return: -1454.6002467078777
# Iteration 34 return: -1431.1617248360317
# Iteration 35 return: -1436.4975283726055
# Iteration 36 return: -1410.2269316872457
# Iteration 37 return: -1452.7790421271573
# Iteration 38 return: -1423.14227243683
# Iteration 39 return: -1361.383174590189
# Iteration 40 return: -1447.4848520050693
# Iteration 41 return: -1463.9570924795667
# Iteration 42 return: -1437.6034267494456
# Iteration 43 return: -1445.337618979197
# Iteration 44 return: -1402.2250261468937
# Iteration 45 return: -1441.1289779293288
# Iteration 46 return: -1434.0602142424384
# Iteration 47 return: -1405.7055922622483
# Iteration 48 return: -1462.3924950331202
# Iteration 49 return: -1429.347102362085
# Iteration 50 return: -1471.3485112914816
# Iteration 51 return: -1449.3573059137414
# Iteration 52 return: -1420.1011920676133
# Iteration 53 return: -1423.511699117037
# Iteration 54 return: -1412.0537888910994
# Iteration 55 return: -1442.3371628330026
# Iteration 56 return: -1471.723562470662
# Iteration 57 return: -1420.5536743591726
# Iteration 58 return: -1415.696860638714
# Iteration 59 return: -1427.732453654278
# Iteration 60 return: -1470.0610312338856
# Iteration 61 return: -1452.3904166553418
# Iteration 62 return: -1419.820508997403
# Iteration 63 return: -1424.9169190164346
# Iteration 64 return: -1430.4910654593446
# Iteration 65 return: -1414.2552348708236
# Iteration 66 return: -1430.9551859882474
# Iteration 67 return: -1409.8761908213546
# Iteration 68 return: -1414.0186915060008
# Iteration 69 return: -1434.903820011889
# Iteration 70 return: -1440.6569184625148
# Iteration 71 return: -1449.5694846269364
# Iteration 72 return: -1423.5558865257601
# Iteration 73 return: -1393.0287103784829
# Iteration 74 return: -1375.8912718901038
# Iteration 75 return: -1428.8668289860834
# Iteration 76 return: -1396.6404000770362
# Iteration 77 return: -1443.281797508523
# Iteration 78 return: -1460.6743020409222
# Iteration 79 return: -1420.9452161546424
# Iteration 80 return: -1406.6169102511305
# Iteration 81 return: -1432.8418946198622
# Iteration 82 return: -1427.7306884536645
# Iteration 83 return: -1469.9138528474916
# Iteration 84 return: -1456.8435598062226
# Iteration 85 return: -1455.943179658701
# Iteration 86 return: -1370.7839997758717
# Iteration 87 return: -1402.5266209936888
# Iteration 88 return: -1414.9684050298358
# Iteration 89 return: -1406.9256257873276
# Iteration 90 return: -1416.3013089571582
# Iteration 91 return: -1446.9921096986284
# Iteration 92 return: -1416.641626175493
# Iteration 93 return: -1445.3799810155358
# Iteration 94 return: -1485.2943497522238
# Iteration 95 return: -1452.1214130417754
# Iteration 96 return: -1404.9717669586528
# Iteration 97 return: -1410.3474627577452
# Iteration 98 return: -1425.660090136708
# Iteration 99 return: -1459.2257055715595
# Iteration 100 return: -1372.2290675167242
# Iteration 101 return: -1417.6854688891333
# Iteration 102 return: -1414.111259807224
# Iteration 103 return: -1425.0179302256554
# Iteration 104 return: -1409.279635858896
# Iteration 105 return: -1452.400574234786
# Iteration 106 return: -1410.790923681433
# Iteration 107 return: -1433.5666457989066
# Iteration 108 return: -1455.45642406332
# Iteration 109 return: -1399.63006235132
# Iteration 110 return: -1413.1773198834558
# Iteration 111 return: -1465.2106576380631
# Iteration 112 return: -1438.9063360803698
# Iteration 113 return: -1444.6043334955225
# Iteration 114 return: -1458.7910853021344
# Iteration 115 return: -1432.0621977476403
# Iteration 116 return: -1445.7208104613549
# Iteration 117 return: -1409.8189134865752
# Iteration 118 return: -1443.047965955461
# Iteration 119 return: -1430.2940081484553
# Iteration 120 return: -1403.0465262699377
# Iteration 121 return: -1444.051527394845
# Iteration 122 return: -1453.973475001951
# Iteration 123 return: -1430.1438760772348
# Iteration 124 return: -1447.8328560380514
# Iteration 125 return: -1430.7889065040026
# Iteration 126 return: -1393.0632637576448
# Iteration 127 return: -1476.842818739768
# Iteration 128 return: -1442.617408274499
# Iteration 129 return: -1438.0540774519804
# Iteration 130 return: -1444.773392847106
# Iteration 131 return: -1401.2550766869635
# Iteration 132 return: -1398.3797728733718
# Iteration 133 return: -1456.1742396340892
# Iteration 134 return: -1432.527736658578
# Iteration 135 return: -1433.314810572993
# Iteration 136 return: -1393.388827517877
# Iteration 137 return: -1424.2924793031564
# Iteration 138 return: -1429.634358813713
# Iteration 139 return: -1456.5020026907946
# Iteration 140 return: -1453.606507526518
# Iteration 141 return: -1396.5690624025526
# Iteration 142 return: -1442.592364922141
# Iteration 143 return: -1428.334223158608
# Iteration 144 return: -1442.9645190039153
# Iteration 145 return: -1401.7680491771177
# Iteration 146 return: -1453.066210654676
# Iteration 147 return: -1392.162099318318
# Iteration 148 return: -1376.3875291041036
# Iteration 149 return: -1448.6615112318843
# Iteration 150 return: -1425.2743383352458
# Iteration 151 return: -1445.4291306175478
# Iteration 152 return: -1474.3792460756997
# Iteration 153 return: -1404.4209060902645
# Iteration 154 return: -1460.7056687758366
# Iteration 155 return: -1440.4606491647598
# Iteration 156 return: -1415.6737131010866
# Iteration 157 return: -1427.337965139579
# Iteration 158 return: -1430.6232419577739
# Iteration 159 return: -1462.1713567706881
# Iteration 160 return: -1452.9218283113528
# Iteration 161 return: -1480.9927940031328
# Iteration 162 return: -1401.8360627306874
# Iteration 163 return: -1465.363140961919
# Iteration 164 return: -1448.3260255004093
# Iteration 165 return: -1438.2530008756494
# Iteration 166 return: -1434.919882797903
# Iteration 167 return: -1382.923414577109
# Iteration 168 return: -1458.4900447875634
# Iteration 169 return: -1437.0604787900486
# Iteration 170 return: -1432.4978759542232
# Iteration 171 return: -1400.9414772684065
# Iteration 172 return: -1438.4259316571492
# Iteration 173 return: -1443.384728442505
# Iteration 174 return: -1414.0298705073199
# Iteration 175 return: -1400.8742620039732
# Iteration 176 return: -1427.01318031637
# Iteration 177 return: -1421.7282346694606
# Iteration 178 return: -1452.0954209861843
# Iteration 179 return: -1392.8685569284607
# Iteration 180 return: -1451.0839773924029
# Iteration 181 return: -1395.8435933073547
# Iteration 182 return: -1403.7961807418242
# Iteration 183 return: -1426.126956097732
# Iteration 184 return: -1399.5734704051974
# Iteration 185 return: -1371.7494423180694
# Iteration 186 return: -1476.5258062810326
# Iteration 187 return: -1450.9539377970373
# Iteration 188 return: -1453.3305858591448
# Iteration 189 return: -1425.474168964376
# Iteration 190 return: -1392.7895347962776
# Iteration 191 return: -1455.6795377330668
# Iteration 192 return: -1445.5055861992762
# Iteration 193 return: -1376.60425072141
# Iteration 194 return: -1421.9726198992382
# Iteration 195 return: -1418.2660549886152
# Iteration 196 return: -1477.2296849071172
# Iteration 197 return: -1431.4061595446492
# Iteration 198 return: -1437.615747282443
# Iteration 199 return: -1381.1029599126118
# Iteration 200 return: -1451.9098982131109
# Iteration 201 return: -1409.340190635516
# Iteration 202 return: -1443.6461918125178
# Iteration 203 return: -1401.104375587801
# Iteration 204 return: -1428.8540177569726
# Iteration 205 return: -1417.9636250707258
# Iteration 206 return: -1452.5018630495294
# Iteration 207 return: -1416.5793512348148
# Iteration 208 return: -1427.9136544991843
# Iteration 209 return: -1418.9587372249862
# Iteration 210 return: -1468.7160666467685
# Iteration 211 return: -1458.0456764852938
# Iteration 212 return: -1420.2937226531096
# Iteration 213 return: -1432.216399870819
# Iteration 214 return: -1437.2520543920932
# Iteration 215 return: -1465.280263478011
# Iteration 216 return: -1468.8171275565028
# Iteration 217 return: -1434.3721691066835
# Iteration 218 return: -1439.50774091073
# Iteration 219 return: -1408.0767662963024
# Iteration 220 return: -1462.1564779472226
# Iteration 221 return: -1428.1021611992333
# Iteration 222 return: -1438.4008554964762
# Iteration 223 return: -1461.7059554527327
# Iteration 224 return: -1407.4463153742129
# Iteration 225 return: -1417.8836274343294
# Iteration 226 return: -1403.602964535455
# Iteration 227 return: -1428.1238903454816
# Iteration 228 return: -1505.0999121278462
# Iteration 229 return: -1444.4402666747073
# Iteration 230 return: -1436.70849240968
# Iteration 231 return: -1414.725708446155
# Iteration 232 return: -1410.8184466303017
# Iteration 233 return: -1460.0573134364063
# Iteration 234 return: -1440.271080583719
# Iteration 235 return: -1429.9137246868636
# Iteration 236 return: -1404.6022814166731
# Iteration 237 return: -1435.1353047348061
# Iteration 238 return: -1431.0024449259415
# Iteration 239 return: -1469.6466032262892
# Iteration 240 return: -1424.6747436726714
# Iteration 241 return: -1454.0906140665275
# Iteration 242 return: -1410.2743742283683
# Iteration 243 return: -1425.4656963317532
# Iteration 244 return: -1476.3162654747814
# Iteration 245 return: -1398.3961031801625
# Iteration 246 return: -1473.4607236582412
# Iteration 247 return: -1413.6672636749222
# Iteration 248 return: -1424.5648013949333
# Iteration 249 return: -1483.610615361035
# Iteration 250 return: -1436.5931725675364
# Iteration 251 return: -1464.6869696481774
# Iteration 252 return: -1429.6213997987907
# Iteration 253 return: -1459.4381530729806
# Iteration 254 return: -1444.215918858101
# Iteration 255 return: -1421.0386027532877
# Iteration 256 return: -1422.4324965208025
# Iteration 257 return: -1433.1554958290856
# Iteration 258 return: -1412.4797501075702
# Iteration 259 return: -1400.3126337341157
# Iteration 260 return: -1448.5890712025016
# Iteration 261 return: -1429.3938193841775
# Iteration 262 return: -1436.8156431187192
# Iteration 263 return: -1407.8271465485232
# Iteration 264 return: -1431.7472506497552
# Iteration 265 return: -1399.3566108808916
# Iteration 266 return: -1421.0794555788425
# Iteration 267 return: -1394.8368931820057
# Iteration 268 return: -1446.33909231813
# Iteration 269 return: -1417.6236726241311
# Iteration 270 return: -1445.2530017879667
# Iteration 271 return: -1430.6706174132476
# Iteration 272 return: -1455.3231520882746
# Iteration 273 return: -1379.8769759778181
# Iteration 274 return: -1428.1877664505505
# Iteration 275 return: -1464.6032642057041
# Iteration 276 return: -1425.7021858886194
# Iteration 277 return: -1435.3163199416797
# Iteration 278 return: -1408.9898341053229
# Iteration 279 return: -1438.9925066918136
# Iteration 280 return: -1444.9696440647047
# Iteration 281 return: -1407.1004458536331
# Iteration 282 return: -1431.0581278874602
# Iteration 283 return: -1432.4557707586202
# Iteration 284 return: -1416.3795941222397
# Iteration 285 return: -1425.6710848790283
# Iteration 286 return: -1441.8857325185402
# Iteration 287 return: -1435.6513594173018
# Iteration 288 return: -1435.220409809922
# Iteration 289 return: -1451.6363828420203
# Iteration 290 return: -1417.1884200760226
# Iteration 291 return: -1437.987970183765
# Iteration 292 return: -1471.457099730838
# Iteration 293 return: -1452.3914601735771
# Iteration 294 return: -1457.9862889438743
# Iteration 295 return: -1433.1911395742
# Iteration 296 return: -1445.5962799401457
# Iteration 297 return: -1431.5577188364728
# Iteration 298 return: -1449.5570662458365
# Iteration 299 return: -1432.253691782821
# Iteration 300 return: -1396.1079213988346
# Iteration 301 return: -1390.5184473128618
# Iteration 302 return: -1411.564072825834
# Iteration 303 return: -1422.6922906525745
# Iteration 304 return: -1464.9955214923373
# Iteration 305 return: -1427.4931588504587
# Iteration 306 return: -1465.5920459009956
# Iteration 307 return: -1394.9529378198336
# Iteration 308 return: -1390.289775748377
# Iteration 309 return: -1442.1570782287915
# Iteration 310 return: -1455.1643081637906
# Iteration 311 return: -1407.2015489761034
# Iteration 312 return: -1445.7951068220038
# Iteration 313 return: -1431.969843239424
# Iteration 314 return: -1478.0999103331567
# Iteration 315 return: -1433.8680254714689
# Iteration 316 return: -1406.670091042891
# Iteration 317 return: -1418.4383976875743
# Iteration 318 return: -1418.3785980111113
# Iteration 319 return: -1442.0267967190346
# Iteration 320 return: -1374.1888998699064
# Iteration 321 return: -1449.1470389110284
# Iteration 322 return: -1441.4657054838415
# Iteration 323 return: -1458.4305514150858
# Iteration 324 return: -1462.0933731237178
# Iteration 325 return: -1380.2848044499506
# Iteration 326 return: -1408.3075023698682
# Iteration 327 return: -1431.9982686908047
# Iteration 328 return: -1394.4067242043466
# Iteration 329 return: -1473.1036667731591
# Iteration 330 return: -1436.0469909478848
# Iteration 331 return: -1408.8848710657285
# Iteration 332 return: -1416.660850946804
# Iteration 333 return: -1371.5858565239237
# Iteration 334 return: -1442.4396626134776
# Iteration 335 return: -1425.700344216687
# Iteration 336 return: -1465.7714013880554
# Iteration 337 return: -1373.16988834188
# Iteration 338 return: -1388.5443872154008
# Iteration 339 return: -1439.1191905101389
# Iteration 340 return: -1452.458908039052
# Iteration 341 return: -1450.9777000351685
# Iteration 342 return: -1458.4263161167999
# Iteration 343 return: -1419.0085797235122
# Iteration 344 return: -1451.2291445599
# Iteration 345 return: -1442.482839995039
# Iteration 346 return: -1403.4917132575997
# Iteration 347 return: -1445.7350362957268
# Iteration 348 return: -1373.9905742518356
# Iteration 349 return: -1501.4851441742853
# Iteration 350 return: -1449.730556489645
# Iteration 351 return: -1405.9009249706319
# Iteration 352 return: -1438.2624827399104
# Iteration 353 return: -1450.544779878147
# Iteration 354 return: -1446.3958279429376
# Iteration 355 return: -1420.9988694856067
# Iteration 356 return: -1426.2761225974
# Iteration 357 return: -1418.051515196388
# Iteration 358 return: -1429.8372293194507
# Iteration 359 return: -1438.0955889256547
# Iteration 360 return: -1435.4816074093555
# Iteration 361 return: -1465.2134238540382
# Iteration 362 return: -1417.5559147966715
# Iteration 363 return: -1379.089979298711
# Iteration 364 return: -1439.7629796033104
# Iteration 365 return: -1437.3088929740588
# Iteration 366 return: -1440.5325600517356
# Iteration 367 return: -1425.5583770545882
# Iteration 368 return: -1457.4091472408547
# Iteration 369 return: -1376.48319953156
# Iteration 370 return: -1438.236272547096
# Iteration 371 return: -1412.4923075289837
# Iteration 372 return: -1434.3786847530305
# Iteration 373 return: -1470.5644685109207
# Iteration 374 return: -1446.6405100378518
# Iteration 375 return: -1412.598250910441
# Iteration 376 return: -1397.6955956633885
# Iteration 377 return: -1410.7213541915019
# Iteration 378 return: -1419.9111951718914
# Iteration 379 return: -1429.6275663547217
# Iteration 380 return: -1459.2732506052405
# Iteration 381 return: -1435.6652801552043
# Iteration 382 return: -1415.4777768995489
# Iteration 383 return: -1452.4680339705262
# Iteration 384 return: -1366.7858292148262
# Iteration 385 return: -1430.2693182669084
# Iteration 386 return: -1395.804408859238
# Iteration 387 return: -1469.4376905711988
# Iteration 388 return: -1435.2757219511395
# Iteration 389 return: -1415.9682990800588
# Iteration 390 return: -1433.8927617152533
# Iteration 391 return: -1431.780257168679
# Iteration 392 return: -1404.5191467773914
# Iteration 393 return: -1387.93547021769
# Iteration 394 return: -1395.2135522459323
# Iteration 395 return: -1409.2381507013242
# Iteration 396 return: -1408.2901671223467
# Iteration 397 return: -1450.9460177283052
# Iteration 398 return: -1390.7559937093656
# Iteration 399 return: -1413.7373924191731
# Iteration 400 return: -1453.1197222347805
# Iteration 401 return: -1429.4677190053526
# Iteration 402 return: -1410.6080724788706
# Iteration 403 return: -1487.473020872455
# Iteration 404 return: -1449.6680660676957
# Iteration 405 return: -1433.1633109458287
# Iteration 406 return: -1454.502469586159
# Iteration 407 return: -1465.0553339303224
# Iteration 408 return: -1443.8776938995718
# Iteration 409 return: -1463.822204727158
# Iteration 410 return: -1433.8279038705057
# Iteration 411 return: -1482.4375807825165
# Iteration 412 return: -1458.3793655680058
# Iteration 413 return: -1440.777947825181
# Iteration 414 return: -1425.18684091378
# Iteration 415 return: -1415.2326141122728
# Iteration 416 return: -1438.4446044249585
# Iteration 417 return: -1429.1632540740384
# Iteration 418 return: -1469.7731033477125
# Iteration 419 return: -1391.3654173465445
# Iteration 420 return: -1375.2481822866823
# Iteration 421 return: -1402.337761659442
# Iteration 422 return: -1379.070530486734
# Iteration 423 return: -1417.3764731412878
# Iteration 424 return: -1431.8001444318083
# Iteration 425 return: -1396.475612308327
# Iteration 426 return: -1413.784887325267
# Iteration 427 return: -1433.4948149454656
# Iteration 428 return: -1466.6048664806597
# Iteration 429 return: -1502.6261306346457
# Iteration 430 return: -1462.1834230963266
# Iteration 431 return: -1445.7948220203073
# Iteration 432 return: -1435.0840158175429
# Iteration 433 return: -1399.6468177459947
# Iteration 434 return: -1482.3990697234992
# Iteration 435 return: -1408.7477584954352
# Iteration 436 return: -1392.6692260089455
# Iteration 437 return: -1454.8153712464994
# Iteration 438 return: -1379.0145418870823
# Iteration 439 return: -1488.1376388114816
# Iteration 440 return: -1438.1684464079763
# Iteration 441 return: -1390.6764568201702
# Iteration 442 return: -1384.315332984229
# Iteration 443 return: -1413.5887849673381
# Iteration 444 return: -1428.6846464410175
# Iteration 445 return: -1407.3589642896814
# Iteration 446 return: -1405.157454092397
# Iteration 447 return: -1428.2756253701386
# Iteration 448 return: -1405.0810952007398
# Iteration 449 return: -1467.6744545550582
# Iteration 450 return: -1455.5078002002836
# Iteration 451 return: -1433.589991540884
# Iteration 452 return: -1425.511641896454
# Iteration 453 return: -1411.9620971386073
# Iteration 454 return: -1449.683582645456
# Iteration 455 return: -1412.8607692492258
# Iteration 456 return: -1383.3445983821277
# Iteration 457 return: -1409.4254107343716
# Iteration 458 return: -1451.0626704523463
# Iteration 459 return: -1446.865417383456
# Iteration 460 return: -1422.9348928501086
# Iteration 461 return: -1403.7957086856911
# Iteration 462 return: -1401.1609981716736
# Iteration 463 return: -1434.7470984424526
# Iteration 464 return: -1427.853713827928
# Iteration 465 return: -1405.5193806761006
# Iteration 466 return: -1457.2310776610548
# Iteration 467 return: -1449.0781237150356
# Iteration 468 return: -1422.7608815890674
# Iteration 469 return: -1468.3185155555543
# Iteration 470 return: -1454.1294120734806
# Iteration 471 return: -1420.471847620507
# Iteration 472 return: -1436.399157550037
# Iteration 473 return: -1420.5724400830331
# Iteration 474 return: -1431.667150963222
# Iteration 475 return: -1410.9052795172731
# Iteration 476 return: -1418.7563222409287
# Iteration 477 return: -1417.5056453751959
# Iteration 478 return: -1442.869703128822
# Iteration 479 return: -1464.8342741709328
# Iteration 480 return: -1481.8983026457515
# Iteration 481 return: -1434.1352183414003
# Iteration 482 return: -1410.5937926264107
# Iteration 483 return: -1388.4126911005626
# Iteration 484 return: -1444.8219700568045
# Iteration 485 return: -1445.5309046019365
# Iteration 486 return: -1432.3176988193889
# Iteration 487 return: -1422.8916073343157
# Iteration 488 return: -1407.7901010395897
# Iteration 489 return: -1397.044847017775
# Iteration 490 return: -1425.435892478625
# Iteration 491 return: -1427.7092088397158
# Iteration 492 return: -1442.926399153558
# Iteration 493 return: -1442.7826382835706
# Iteration 494 return: -1423.3736790548264
# Iteration 495 return: -1423.8293293723154
# Iteration 496 return: -1405.5685492795085
# Iteration 497 return: -1438.1848486960307
# Iteration 498 return: -1418.8984140740458
# Iteration 499 return: -1440.568634845987
#
# ==== Training Run 2 ====
# Iteration 0 return: -1420.0842616437749
# Iteration 1 return: -1392.0709364733846
# Iteration 2 return: -1415.8810701161065
# Iteration 3 return: -1445.5272875718836
# Iteration 4 return: -1448.0862704760955
# Iteration 5 return: -1445.7665032313269
# Iteration 6 return: -1442.8551195807506
# Iteration 7 return: -1433.4262854571143
# Iteration 8 return: -1432.8984848790615
# Iteration 9 return: -1468.8427600673585
# Iteration 10 return: -1426.5065920078257
# Iteration 11 return: -1410.2275389727329
# Iteration 12 return: -1446.6746983473934
# Iteration 13 return: -1456.758622711692
# Iteration 14 return: -1437.279748164881
# Iteration 15 return: -1417.7711512726546
# Iteration 16 return: -1389.9582418552661
# Iteration 17 return: -1449.4915263892399
# Iteration 18 return: -1433.038260261137
# Iteration 19 return: -1435.9304333319762
# Iteration 20 return: -1420.3397984389712
# Iteration 21 return: -1444.1235726816703
# Iteration 22 return: -1429.2746807688848
# Iteration 23 return: -1415.5530366184066
# Iteration 24 return: -1428.8023096142338
# Iteration 25 return: -1424.811842311596
# Iteration 26 return: -1436.281186684519
# Iteration 27 return: -1412.101114365682
# Iteration 28 return: -1426.9025934841422
# Iteration 29 return: -1419.6188666331457
# Iteration 30 return: -1415.1696070757507
# Iteration 31 return: -1426.5786937034502
# Iteration 32 return: -1418.4389106030515
# Iteration 33 return: -1405.0784229330222
# Iteration 34 return: -1420.6874603236963
# Iteration 35 return: -1384.513284305061
# Iteration 36 return: -1416.2421838631979
# Iteration 37 return: -1403.0663561103306
# Iteration 38 return: -1469.18055496322
# Iteration 39 return: -1468.9483396841213
# Iteration 40 return: -1425.6876434700066
# Iteration 41 return: -1436.9551597210268
# Iteration 42 return: -1420.7151266518856
# Iteration 43 return: -1461.4588021124714
# Iteration 44 return: -1403.601245111345
# Iteration 45 return: -1416.4168271548983
# Iteration 46 return: -1436.5047607564927
# Iteration 47 return: -1438.4051442189887
# Iteration 48 return: -1379.435744519184
# Iteration 49 return: -1440.145227211987
# Iteration 50 return: -1370.0992846512795
# Iteration 51 return: -1480.3987474781957
# Iteration 52 return: -1448.613936486238
# Iteration 53 return: -1448.4650741327305
# Iteration 54 return: -1404.0747570218393
# Iteration 55 return: -1438.654758337587
# Iteration 56 return: -1424.9571261930962
# Iteration 57 return: -1392.6848776682466
# Iteration 58 return: -1431.9009242398727
# Iteration 59 return: -1436.9777944049363
# Iteration 60 return: -1452.7841662439082
# Iteration 61 return: -1459.2658013679336
# Iteration 62 return: -1414.1715529952571
# Iteration 63 return: -1398.9566165273884
# Iteration 64 return: -1431.017212525333
# Iteration 65 return: -1428.5251496115823
# Iteration 66 return: -1431.0593290206975
# Iteration 67 return: -1430.1702798762171
# Iteration 68 return: -1405.826256052355
# Iteration 69 return: -1333.4668210210402
# Iteration 70 return: -1393.022258424461
# Iteration 71 return: -1453.7387974437079
# Iteration 72 return: -1410.3005351281602
# Iteration 73 return: -1361.2585212157792
# Iteration 74 return: -1383.9299833027894
# Iteration 75 return: -1471.015372782871
# Iteration 76 return: -1441.4892238837294
# Iteration 77 return: -1449.9841310188422
# Iteration 78 return: -1422.1222205062957
# Iteration 79 return: -1442.859768376518
# Iteration 80 return: -1428.160629878988
# Iteration 81 return: -1475.4112178616226
# Iteration 82 return: -1460.6206573378047
# Iteration 83 return: -1409.6260045175502
# Iteration 84 return: -1405.4913882225007
# Iteration 85 return: -1448.2009503138872
# Iteration 86 return: -1442.2406768062463
# Iteration 87 return: -1413.041305658215
# Iteration 88 return: -1405.115075720201
# Iteration 89 return: -1430.8739721805355
# Iteration 90 return: -1487.3209317703297
# Iteration 91 return: -1451.703867596512
# Iteration 92 return: -1457.6352602060635
# Iteration 93 return: -1386.5182574999333
# Iteration 94 return: -1368.8376239420784
# Iteration 95 return: -1447.09780516486
# Iteration 96 return: -1447.547799492112
# Iteration 97 return: -1393.324642816186
# Iteration 98 return: -1429.8352944040546
# Iteration 99 return: -1418.5306455172847
# Iteration 100 return: -1421.323535474042
# Iteration 101 return: -1452.2838493965255
# Iteration 102 return: -1406.6858417879728
# Iteration 103 return: -1414.2571399140668
# Iteration 104 return: -1455.0168681550151
# Iteration 105 return: -1378.81582280421
# Iteration 106 return: -1462.2456776540355
# Iteration 107 return: -1424.6400486261211
# Iteration 108 return: -1428.587275411884
# Iteration 109 return: -1451.0976921323686
# Iteration 110 return: -1466.2996322241922
# Iteration 111 return: -1409.1664568213373
# Iteration 112 return: -1442.3406405024728
# Iteration 113 return: -1442.146769849298
# Iteration 114 return: -1427.3574986594977
# Iteration 115 return: -1433.9439038334663
# Iteration 116 return: -1443.222756670614
# Iteration 117 return: -1397.7398873330155
# Iteration 118 return: -1396.7390158433716
# Iteration 119 return: -1430.1132998496046
# Iteration 120 return: -1448.3831807174286
# Iteration 121 return: -1493.3978840705504
# Iteration 122 return: -1396.509826467596
# Iteration 123 return: -1419.4924362673237
# Iteration 124 return: -1506.005174794638
# Iteration 125 return: -1455.561997468397
# Iteration 126 return: -1434.4569703676302
# Iteration 127 return: -1449.1281557866744
# Iteration 128 return: -1473.1435512831806
# Iteration 129 return: -1426.6262680606544
# Iteration 130 return: -1434.1246326948703
# Iteration 131 return: -1431.1623904583664
# Iteration 132 return: -1405.8652085172137
# Iteration 133 return: -1395.9932930782002
# Iteration 134 return: -1401.7575253549094
# Iteration 135 return: -1466.0829762234787
# Iteration 136 return: -1459.5355298594386
# Iteration 137 return: -1474.6441517859448
# Iteration 138 return: -1418.1185752041513
# Iteration 139 return: -1420.2598024492959
# Iteration 140 return: -1405.1567581575116
# Iteration 141 return: -1424.0166804629316
# Iteration 142 return: -1407.9874020755788
# Iteration 143 return: -1437.5646562743746
# Iteration 144 return: -1417.0194660724203
# Iteration 145 return: -1430.1497519609084
# Iteration 146 return: -1394.954867531533
# Iteration 147 return: -1414.3907240333283
# Iteration 148 return: -1412.3038907747095
# Iteration 149 return: -1386.1029194493653
# Iteration 150 return: -1400.9898825374992
# Iteration 151 return: -1470.887480382137
# Iteration 152 return: -1442.668610480825
# Iteration 153 return: -1463.2390739981086
# Iteration 154 return: -1378.2847127876182
# Iteration 155 return: -1464.632485437536
# Iteration 156 return: -1432.5577557668835
# Iteration 157 return: -1420.1944710259884
# Iteration 158 return: -1396.0003108718122
# Iteration 159 return: -1471.7160906179001
# Iteration 160 return: -1416.2126908828318
# Iteration 161 return: -1441.858133499945
# Iteration 162 return: -1434.009481679077
# Iteration 163 return: -1408.3057322298985
# Iteration 164 return: -1408.360242672991
# Iteration 165 return: -1406.688974756195
# Iteration 166 return: -1369.0526349553713
# Iteration 167 return: -1400.6784587919526
# Iteration 168 return: -1426.646392573261
# Iteration 169 return: -1431.9243994453177
# Iteration 170 return: -1421.2347883633959
# Iteration 171 return: -1449.8347632975008
# Iteration 172 return: -1402.823090509344
# Iteration 173 return: -1434.2899199006397
# Iteration 174 return: -1416.8335216982662
# Iteration 175 return: -1425.0427246345953
# Iteration 176 return: -1432.899396006434
# Iteration 177 return: -1429.9312700969292
# Iteration 178 return: -1461.9734840158187
# Iteration 179 return: -1395.921512770032
# Iteration 180 return: -1418.4359945176045
# Iteration 181 return: -1472.8821018132444
# Iteration 182 return: -1455.855904226154
# Iteration 183 return: -1403.635012530467
# Iteration 184 return: -1444.952196339046
# Iteration 185 return: -1414.5342213982096
# Iteration 186 return: -1394.429127365599
# Iteration 187 return: -1413.3747998268343
# Iteration 188 return: -1455.8991053429122
# Iteration 189 return: -1456.030848369288
# Iteration 190 return: -1391.2582989222433
# Iteration 191 return: -1446.403629642191
# Iteration 192 return: -1366.8918266183946
# Iteration 193 return: -1453.47941105855
# Iteration 194 return: -1419.1122166770758
# Iteration 195 return: -1428.0808016355645
# Iteration 196 return: -1448.5515067612132
# Iteration 197 return: -1438.9121992851544
# Iteration 198 return: -1442.5958658396887
# Iteration 199 return: -1484.6915048025053
# Iteration 200 return: -1435.6500811061885
# Iteration 201 return: -1421.795442894486
# Iteration 202 return: -1412.8675999303907
# Iteration 203 return: -1415.2246771566943
# Iteration 204 return: -1413.6276136942456
# Iteration 205 return: -1433.7278383313492
# Iteration 206 return: -1385.0885371082898
# Iteration 207 return: -1434.9097432416304
# Iteration 208 return: -1445.6417323870585
# Iteration 209 return: -1377.526910253962
# Iteration 210 return: -1448.2553256033857
# Iteration 211 return: -1396.1106504859279
# Iteration 212 return: -1427.3812802780171
# Iteration 213 return: -1459.5826136984738
# Iteration 214 return: -1461.7760512408304
# Iteration 215 return: -1409.5802864882846
# Iteration 216 return: -1439.9868808699896
# Iteration 217 return: -1420.5059321327508
# Iteration 218 return: -1407.3648582639607
# Iteration 219 return: -1451.6105305674237
# Iteration 220 return: -1443.3188846612163
# Iteration 221 return: -1444.3224651572045
# Iteration 222 return: -1419.73113430392
# Iteration 223 return: -1454.0468743133297
# Iteration 224 return: -1394.7170854198437
# Iteration 225 return: -1444.7967987769034
# Iteration 226 return: -1461.4588804237048
# Iteration 227 return: -1453.7556547680808
# Iteration 228 return: -1413.1990063773344
# Iteration 229 return: -1442.3664517669877
# Iteration 230 return: -1437.9049835684896
# Iteration 231 return: -1405.8835088958901
# Iteration 232 return: -1402.9628690803052
# Iteration 233 return: -1425.9330299084386
# Iteration 234 return: -1441.3763477434466
# Iteration 235 return: -1420.7217300587893
# Iteration 236 return: -1451.9131329197685
# Iteration 237 return: -1436.9695803820591
# Iteration 238 return: -1472.7295061595862
# Iteration 239 return: -1423.796603520587
# Iteration 240 return: -1448.2774106544505
# Iteration 241 return: -1439.0569809753447
# Iteration 242 return: -1420.5893791278825
# Iteration 243 return: -1461.9056995626788
# Iteration 244 return: -1424.4498619898905
# Iteration 245 return: -1421.4083102304737
# Iteration 246 return: -1403.215519453467
# Iteration 247 return: -1401.641578707695
# Iteration 248 return: -1454.5782583936366
# Iteration 249 return: -1439.3544542656343
# Iteration 250 return: -1426.951003157844
# Iteration 251 return: -1402.167680040424
# Iteration 252 return: -1461.8625390584332
# Iteration 253 return: -1403.310403704395
# Iteration 254 return: -1446.177726080281
# Iteration 255 return: -1433.9258042096285
# Iteration 256 return: -1459.4477951530243
# Iteration 257 return: -1462.0713260760097
# Iteration 258 return: -1443.9637629691697
# Iteration 259 return: -1452.8542797664988
# Iteration 260 return: -1429.1687135461718
# Iteration 261 return: -1402.918586418132
# Iteration 262 return: -1408.1318134043863
# Iteration 263 return: -1456.37624672375
# Iteration 264 return: -1438.755580909631
# Iteration 265 return: -1440.5294687018047
# Iteration 266 return: -1403.5047247997672
# Iteration 267 return: -1438.5680636199377
# Iteration 268 return: -1473.4012335503971
# Iteration 269 return: -1420.4376143364796
# Iteration 270 return: -1451.9694364801546
# Iteration 271 return: -1438.0943947008625
# Iteration 272 return: -1409.280369564568
# Iteration 273 return: -1433.112539234888
# Iteration 274 return: -1409.1456916801135
# Iteration 275 return: -1398.562894120415
# Iteration 276 return: -1475.5506948852415
# Iteration 277 return: -1404.7686171026467
# Iteration 278 return: -1444.8256144584716
# Iteration 279 return: -1448.5995850162394
# Iteration 280 return: -1462.7324471374043
# Iteration 281 return: -1450.1873567748628
# Iteration 282 return: -1497.0210340010499
# Iteration 283 return: -1430.007604932369
# Iteration 284 return: -1459.0566147059203
# Iteration 285 return: -1481.3340918182332
# Iteration 286 return: -1416.4816863970955
# Iteration 287 return: -1417.0265502013017
# Iteration 288 return: -1451.013930273472
# Iteration 289 return: -1458.256299466205
# Iteration 290 return: -1454.2678431892023
# Iteration 291 return: -1443.8322487627902
# Iteration 292 return: -1413.8337777365248
# Iteration 293 return: -1445.7586052987103
# Iteration 294 return: -1416.3785498352286
# Iteration 295 return: -1433.200029462197
# Iteration 296 return: -1445.1510406048844
# Iteration 297 return: -1476.2320996553885
# Iteration 298 return: -1428.3426773528631
# Iteration 299 return: -1430.127086083504
# Iteration 300 return: -1444.7982013288822
# Iteration 301 return: -1434.3344798859457
# Iteration 302 return: -1393.1513665014133
# Iteration 303 return: -1485.8842079778638
# Iteration 304 return: -1414.8972545511958
# Iteration 305 return: -1448.8984773920477
# Iteration 306 return: -1438.2304920982074
# Iteration 307 return: -1400.7754227866355
# Iteration 308 return: -1401.07763166671
# Iteration 309 return: -1376.043815016796
# Iteration 310 return: -1430.2568153743819
# Iteration 311 return: -1419.3089197046806
# Iteration 312 return: -1414.5660477321967
# Iteration 313 return: -1436.1888253160068
# Iteration 314 return: -1433.2918659346426
# Iteration 315 return: -1449.787675440659
# Iteration 316 return: -1460.0958156460647
# Iteration 317 return: -1424.9341229813422
# Iteration 318 return: -1439.3828709822644
# Iteration 319 return: -1417.1145702993435
# Iteration 320 return: -1428.8736482843633
# Iteration 321 return: -1412.9085274651648
# Iteration 322 return: -1456.9169879294063
# Iteration 323 return: -1463.3108600379776
# Iteration 324 return: -1425.6601791559035
# Iteration 325 return: -1438.5887895102799
# Iteration 326 return: -1414.748438592255
# Iteration 327 return: -1431.5785181768301
# Iteration 328 return: -1468.5758989534652
# Iteration 329 return: -1424.8485543636232
# Iteration 330 return: -1462.6779841541872
# Iteration 331 return: -1455.6316798046107
# Iteration 332 return: -1362.6130967509125
# Iteration 333 return: -1444.271824359397
# Iteration 334 return: -1410.5615975241114
# Iteration 335 return: -1463.6000698686266
# Iteration 336 return: -1401.502459955712
# Iteration 337 return: -1417.0540788163244
# Iteration 338 return: -1415.5152158887934
# Iteration 339 return: -1400.9678766626803
# Iteration 340 return: -1445.5078599254414
# Iteration 341 return: -1406.1532217695192
# Iteration 342 return: -1424.4925910830125
# Iteration 343 return: -1418.3365263493918
# Iteration 344 return: -1401.380370677126
# Iteration 345 return: -1445.3641260161376
# Iteration 346 return: -1435.0445869628215
# Iteration 347 return: -1412.3292208386958
# Iteration 348 return: -1383.82580413909
# Iteration 349 return: -1460.6143101438258
# Iteration 350 return: -1397.0879627905476
# Iteration 351 return: -1427.9345448697234
# Iteration 352 return: -1445.4218891128526
# Iteration 353 return: -1362.280691929739
# Iteration 354 return: -1435.807770375895
# Iteration 355 return: -1406.8999374588702
# Iteration 356 return: -1424.2504829923312
# Iteration 357 return: -1408.1036583816694
# Iteration 358 return: -1428.600542329705
# Iteration 359 return: -1490.485323112905
# Iteration 360 return: -1435.7595175342572
# Iteration 361 return: -1410.856766780354
# Iteration 362 return: -1443.7738530204756
# Iteration 363 return: -1451.2044833149512
# Iteration 364 return: -1462.4024117091733
# Iteration 365 return: -1441.1695462935543
# Iteration 366 return: -1455.4926311754125
# Iteration 367 return: -1432.6286030685158
# Iteration 368 return: -1446.8246361962208
# Iteration 369 return: -1445.7434008741939
# Iteration 370 return: -1454.5664127319803
# Iteration 371 return: -1430.6374911570797
# Iteration 372 return: -1440.468268356907
# Iteration 373 return: -1430.1847942587424
# Iteration 374 return: -1441.3100191751619
# Iteration 375 return: -1405.9254612368159
# Iteration 376 return: -1453.6846842423827
# Iteration 377 return: -1445.2720612719904
# Iteration 378 return: -1418.4479117613037
# Iteration 379 return: -1423.1706186672113
# Iteration 380 return: -1453.0799027933367
# Iteration 381 return: -1456.2898551546036
# Iteration 382 return: -1421.2480414251984
# Iteration 383 return: -1417.6776064800472
# Iteration 384 return: -1422.9171360866662
# Iteration 385 return: -1422.6895412713288
# Iteration 386 return: -1360.1874798835877
# Iteration 387 return: -1429.7904218098458
# Iteration 388 return: -1432.0907382470184
# Iteration 389 return: -1412.8985318849236
# Iteration 390 return: -1405.5488489910713
# Iteration 391 return: -1435.0955580701368
# Iteration 392 return: -1461.2449294591447
# Iteration 393 return: -1419.401950846538
# Iteration 394 return: -1463.0831209750224
# Iteration 395 return: -1442.3558539931353
# Iteration 396 return: -1410.272902955655
# Iteration 397 return: -1431.400288698282
# Iteration 398 return: -1463.4279535948795
# Iteration 399 return: -1444.006482908999
# Iteration 400 return: -1436.061931303392
# Iteration 401 return: -1421.3973927179288
# Iteration 402 return: -1425.9023367876994
# Iteration 403 return: -1410.0936346772314
# Iteration 404 return: -1444.4359414897363
# Iteration 405 return: -1462.1147293123604
# Iteration 406 return: -1464.7322518860053
# Iteration 407 return: -1490.5309292939803
# Iteration 408 return: -1432.7130735281607
# Iteration 409 return: -1380.8520883062295
# Iteration 410 return: -1433.686628286764
# Iteration 411 return: -1479.0694892221502
# Iteration 412 return: -1420.490608366405
# Iteration 413 return: -1405.9057481983925
# Iteration 414 return: -1421.6459307806876
# Iteration 415 return: -1444.6822889569403
# Iteration 416 return: -1389.9001034924263
# Iteration 417 return: -1438.1521061065794
# Iteration 418 return: -1430.9188853532573
# Iteration 419 return: -1426.3576941136519
# Iteration 420 return: -1467.8437627646824
# Iteration 421 return: -1406.188140864093
# Iteration 422 return: -1391.809954855591
# Iteration 423 return: -1440.8505373984576
# Iteration 424 return: -1422.6437897132337
# Iteration 425 return: -1442.5844767982016
# Iteration 426 return: -1442.512342142258
# Iteration 427 return: -1452.0825955666414
# Iteration 428 return: -1446.589965584514
# Iteration 429 return: -1482.3609908779338
# Iteration 430 return: -1447.5075409461372
# Iteration 431 return: -1499.9534044262023
# Iteration 432 return: -1463.8313906752692
# Iteration 433 return: -1400.2840594607094
# Iteration 434 return: -1452.9027273267136
# Iteration 435 return: -1445.995442357709
# Iteration 436 return: -1407.6993695909778
# Iteration 437 return: -1414.4799295268954
# Iteration 438 return: -1462.2405502629654
# Iteration 439 return: -1436.3029778332386
# Iteration 440 return: -1395.2562881721183
# Iteration 441 return: -1456.3185391327615
# Iteration 442 return: -1490.0719473471245
# Iteration 443 return: -1471.1582405675078
# Iteration 444 return: -1437.4408608424726
# Iteration 445 return: -1400.2648459198574
# Iteration 446 return: -1451.4726977520809
# Iteration 447 return: -1462.794539595091
# Iteration 448 return: -1437.6534071627818
# Iteration 449 return: -1428.385698765833
# Iteration 450 return: -1423.0794657303145
# Iteration 451 return: -1416.0178062197256
# Iteration 452 return: -1394.0175829114517
# Iteration 453 return: -1408.1053848657261
# Iteration 454 return: -1467.343930265177
# Iteration 455 return: -1394.9564203439404
# Iteration 456 return: -1417.1298066434015
# Iteration 457 return: -1466.1891159776226
# Iteration 458 return: -1457.7459879558596
# Iteration 459 return: -1462.1953449171906
# Iteration 460 return: -1443.8830206044638
# Iteration 461 return: -1449.611566678745
# Iteration 462 return: -1445.1054737990846
# Iteration 463 return: -1415.9797284289573
# Iteration 464 return: -1473.1570080605397
# Iteration 465 return: -1426.5658279923598
# Iteration 466 return: -1412.1175691652795
# Iteration 467 return: -1453.532152402196
# Iteration 468 return: -1449.942266731312
# Iteration 469 return: -1454.351313539259
# Iteration 470 return: -1476.0515621022819
# Iteration 471 return: -1417.7312699313338
# Iteration 472 return: -1434.1883631598764
# Iteration 473 return: -1449.1531320983854
# Iteration 474 return: -1432.7319942866764
# Iteration 475 return: -1441.0336467360644
# Iteration 476 return: -1451.4253154199073
# Iteration 477 return: -1431.4503046461816
# Iteration 478 return: -1435.589707539305
# Iteration 479 return: -1423.1029495048895
# Iteration 480 return: -1408.2195935382445
# Iteration 481 return: -1459.7058991813412
# Iteration 482 return: -1438.6485747896259
# Iteration 483 return: -1444.0669347621065
# Iteration 484 return: -1430.079699594453
# Iteration 485 return: -1402.6754807544437
# Iteration 486 return: -1496.2627204642072
# Iteration 487 return: -1404.8491171931228
# Iteration 488 return: -1419.7194124410673
# Iteration 489 return: -1443.6900124897809
# Iteration 490 return: -1459.9885036966205
# Iteration 491 return: -1379.2927855146243
# Iteration 492 return: -1448.4867330769573
# Iteration 493 return: -1415.295293743896
# Iteration 494 return: -1413.3897117499139
# Iteration 495 return: -1409.4009661357725
# Iteration 496 return: -1456.2728983956204
# Iteration 497 return: -1464.6816310379468
# Iteration 498 return: -1416.4654210303227
# Iteration 499 return: -1457.3686843647124

# %%
# collect saved results
import numpy as np
r1 = np.genfromtxt("InvertedPendulum_results.csv", delimiter=",")
all_results = [r1]
labels = ["REINFORCE"]

##############################################################
# Plot your Policy Gradient results below
##############################################################
# %matplotlib inline

from matplotlib import pyplot as plt
import numpy as np

#some example data
x= np.linspace(0, 499, 500)
# c1 = np.cumsum(r1,axis=1)
# y = np.mean(c1, axis=0)
# y_lb = np.min(c1,axis=0)
# y_ub = np.max(c1,axis=0)

y = np.mean(r1, axis=0)
y_lb = np.min(r1,axis=0)
y_ub = np.max(r1,axis=0)


fig, ax = plt.subplots()
ax.plot(x,y)
ax.fill_between(x, y_lb, y_ub, color='b', alpha=.1)
ax.set_title('The performance of policy gradient')
plt.xlabel('No of iterations')
plt.ylabel('Cumulative return')
plt.legend(labels)
# fig = plot_results(all_results, labels)
